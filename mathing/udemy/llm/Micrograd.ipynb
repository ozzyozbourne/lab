# %%
import math 
import numpy as np 
import matplotlib.pyplot as plt 
import torch
# %matplotlib inline

# %%
def f(x): return 3*x**2 - 4*x + 5
f(3.0)
# Out:
# 20.0

# %%
xp = np.arange

# %%
x = torch.tensor(2.0, requires_grad=True)
y = 3*x**2 - 4*x + 5
y.backward()      # PyTorch calculates dy/dx automatically
print(x.grad)
# Out:
# tensor(8.)
